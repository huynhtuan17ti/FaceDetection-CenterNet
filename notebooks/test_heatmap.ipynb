# %%
# %load_ext autoreload
# %autoreload 2
# %run ~/Machine_Learning/FaceDetection-CenterNet/startup.py

# %%
show_heatmap('/home/ryan/Machine_Learning/FaceDetection-CenterNet/heatmap.yaml', '/home/ryan/Machine_Learning/FaceDetection-CenterNet/images')
# Out:
# => loading pretrained model https://download.pytorch.org/models/resnet18-5c106cde.pth
# => init deconv weights from normal distribution
# Load model successfully!
