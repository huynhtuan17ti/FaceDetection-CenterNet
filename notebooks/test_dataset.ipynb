# %%
# %load_ext autoreload
# %autoreload 2
# %run ~/Machine_Learning/FaceDetection-CenterNet/startup.py

# %%
show_dataset('/home/ryan/Machine_Learning/FaceDetection-CenterNet/heatmap.yaml', '/home/ryan/Machine_Learning/FaceDetection-CenterNet/src/dataset/wider_face/WIDER_val')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
